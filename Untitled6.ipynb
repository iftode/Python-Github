# %% [markdown]
# <a href="https://colab.research.google.com/github/iftode/Python-Github/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install boto3
# !pip install botocore
# !pip install google-colab
# !pip install pandas
# !pip install google-cloud-storage
# !pip install google-cloud-bigquery
# !pip install google-cloud-bigquery-storage

# %%
import boto3
from botocore.exceptions import ClientError, EndpointConnectionError, NoCredentialsError
from google.colab import userdata
from io import StringIO
import pandas as pd

# Read credentials from secrets
aws_access_key = userdata.get('AWS_ACCESS_KEY')
aws_secret_key = userdata.get('AWS_SECRET_KEY')

# Create a signed S3 client with user credentials
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# %%
# Specify the bucket name
bucket_name = 'music-top-charts'

# Get list of all .csv files from the bucket
response = s3.list_objects_v2 (Bucket=bucket_name)
csv_keys =[obj['Key'] for obj in response.get('Contents',[]) if obj['Key'].endswith('.csv')]

# Read all CSVs into a single DataFrame
dataframes = []
for keys in csv_keys:
  obj = s3.get_object(Bucket=bucket_name, Key=keys)
  csv_data = obj['Body'].read().decode('utf-8-sig')
  df = pd.read_csv(StringIO(csv_data))
  dataframes.append(df)

  # Combine all daily lista into one big DataFrame
  combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_d.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1820 entries, 0 to 1819
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track             1820 non-null   object
#  1   artist            1820 non-null   object
#  2   appearances       20 non-null     float64
#  3   average_position  20 non-null     float64
#  4   position          1800 non-null   float64
#  5   album             1711 non-null   object
#  6   duration          1800 non-null   float64
#  7   date              1800 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 113.9+ KB
#               track         artist  appearances  average_position  position  \
# 0          Ordinary    Alex Warren         56.0         10.964286       NaN
# 1  Beautiful Things   Benson Boone         46.0         10.673913       NaN
# 2             Messy     Lola Young         42.0         12.119048       NaN
# ...

# %%
# Group by track and artist: count appearances, sum positions
ranking = combined_df.groupby(['track', 'artist']).agg(
    appearances=('position', 'count'),
    total_score=('position', 'sum')
).reset_index()

# Compute average position
ranking['average_position'] = ranking['total_score'] / ranking['appearances']

# Sort by most appearances and lowest average position
top_20 = ranking.sort_values(
    by=['appearances', 'average_position'],
    ascending=[False, True]
).head(20)[[
    'track', 'artist', 'appearances', 'average_position'
]].reset_index(drop=True)

top_20
# Out:
#                                track             artist  appearances  \
# 0                           Ordinary        Alex Warren           56
# 1                   Beautiful Things       Benson Boone           46
# 2                              Messy         Lola Young           42
# 3                       Lose Control        Teddy Swims           41
# 4                     Pink Pony Club      Chappell Roan           37
# 5                           Manchild  Sabrina Carpenter           35
# 6                           Espresso  Sabrina Carpenter           31
# 7                            Anxiety            Doechii           31
# 8                 BIRDS OF A FEATHER      Billie Eilish           29
# 9                   End of the World        Miley Cyrus           29
# 10                        WILDFLOWER      Billie Eilish           26
# 11                       Love Me Not        Ravyn Lenae           24
# 12  Die With A Smile (w/ Bruno Mars)          Lady Gaga           22
# ...

# %%
import boto3
from botocore.exceptions import ClientError, EndpointConnectionError, NoCredentialsError
from google.colab import userdata
from io import StringIO
import pandas as pd

# Read credentials from secrets
aws_access_key = userdata.get('AWS_ACCESS_KEY')
aws_secret_key = userdata.get('AWS_SECRET_KEY')

# Create a signed S3 client with user credentials
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# Specify the bucket name
bucket_name = 'music-top-charts'

# Get list of all .csv files from the bucket
response = s3.list_objects_v2(Bucket=bucket_name)
csv_keys = [obj['Key'] for obj in response.get('Contents', []) if obj['Key'].endswith('.csv')]

# Read all CSVs into a single DataFrame
dataframes = []
for key in csv_keys:
    obj = s3.get_object(Bucket=bucket_name, Key=key)
    csv_data = obj['Body'].read().decode('utf-8-sig')
    df = pd.read_csv(StringIO(csv_data))
    dataframes.append(df)

# Combine all daily lists into one big DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Clean column names (just in case)
combined_df.columns = combined_df.columns.str.strip().str.lower()

# Group by track and artist: count appearances, sum positions
ranking = combined_df.groupby(['track', 'artist']).agg(
    appearances=('position', 'count'),
    total_score=('position', 'sum'),
    highest_position=('position', 'min'),
    lowest_position=('position', 'max'),
    day_on_top=('position', lambda x: (x == 1).sum())
).reset_index()

ranking['average_position'] = ranking['total_score'] / ranking['appearances']

# Sort by most appearances and lowest average position
top_20 = ranking.sort_values(
    by=['appearances', 'average_position'],
    ascending=[False, True]
).head(20)[[
    'track', 'artist', 'appearances', 'average_position',
    'highest_position', 'lowest_position', 'day_on_top'
]]

# Show the result
top_20
# Out:
#                                 track             artist  appearances  \
# 76                           Ordinary        Alex Warren           56
# 19                   Beautiful Things       Benson Boone           46
# 65                              Messy         Lola Young           42
# 56                       Lose Control        Teddy Swims           41
# 77                     Pink Pony Club      Chappell Roan           37
# 62                           Manchild  Sabrina Carpenter           35
# 31                           Espresso  Sabrina Carpenter           31
# 10                            Anxiety            Doechii           31
# 14                 BIRDS OF A FEATHER      Billie Eilish           29
# 29                   End of the World        Miley Cyrus           29
# 112                        WILDFLOWER      Billie Eilish           26
# 57                        Love Me Not        Ravyn Lenae           24
# ...

# %%
import boto3
from botocore.exceptions import ClientError, EndpointConnectionError, NoCredentialsError
from google.colab import userdata
from io import StringIO
import pandas as pd

# Read credentials from secrets
aws_access_key = userdata.get('AWS_ACCESS_KEY')
aws_secret_key = userdata.get('AWS_SECRET_KEY')

# Create a signed S3 client with user credentials
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# Specify the bucket name
bucket_name = 'music-top-charts'

# Get list of all .csv files from the bucket
response = s3.list_objects_v2(Bucket=bucket_name)
csv_keys = [obj['Key'] for obj in response.get('Contents', []) if obj['Key'].endswith('.csv')]

# Read all CSVs into a single DataFrame
dataframes = []
for key in csv_keys:
    obj = s3.get_object(Bucket=bucket_name, Key=key)
    csv_data = obj['Body'].read().decode('utf-8-sig')
    df = pd.read_csv(StringIO(csv_data))
    dataframes.append(df)

# Combine all daily lists into one big DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Clean column names (just in case)
combined_df.columns = combined_df.columns.str.strip().str.lower()

# Group by track and artist: count appearances, sum positions
ranking = combined_df.groupby(['track', 'artist']).agg(
    appearances=('position', 'count'),
    total_score=('position', 'sum'),
    highest_position=('position', 'min'),
    lowest_position=('position', 'max'),
    day_on_top=('position', lambda x: (x == 1).sum())
).reset_index()

ranking['average_position'] = ranking['total_score'] / ranking['appearances']

# Sort by most appearances and lowest average position
top_20 = ranking.sort_values(
    by=['appearances', 'average_position'],
    ascending=[False, True]
).head(20)[[
    'track', 'artist', 'appearances', 'average_position',
    'highest_position', 'lowest_position', 'day_on_top'
]]

# Show the result
top_20
# Out:
#                                 track             artist  appearances  \
# 76                           Ordinary        Alex Warren           56
# 19                   Beautiful Things       Benson Boone           46
# 65                              Messy         Lola Young           42
# 56                       Lose Control        Teddy Swims           41
# 77                     Pink Pony Club      Chappell Roan           37
# 62                           Manchild  Sabrina Carpenter           35
# 31                           Espresso  Sabrina Carpenter           31
# 10                            Anxiety            Doechii           31
# 14                 BIRDS OF A FEATHER      Billie Eilish           29
# 29                   End of the World        Miley Cyrus           29
# 112                        WILDFLOWER      Billie Eilish           26
# 57                        Love Me Not        Ravyn Lenae           24
# ...
